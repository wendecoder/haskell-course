-- %% [markdown]
-- # Improving and combining functions

-- %% [markdown]
-- ## Outline
--
-- - Higher order functions
-- - Curried functions
-- - Partial application
-- - Applying and composing functions (`$` and `.` operators)
-- - Lambda functions
